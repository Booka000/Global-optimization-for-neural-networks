# %%
import numpy as np
import tensorflow as tf
import import_ipynb
from NN import get_dataset, get_model, get_shape, set_shape, get_con_mat, LossHistory
import matplotlib.pyplot as plt
import json
import os
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
model = get_model()

# %%
loss_history = LossHistory()

# %%
model.compile(optimizer='adam', loss="binary_crossentropy", metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 10, epochs = 13, verbose = 1,callbacks=[loss_history])
# Out:
# Epoch 1/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4565 - accuracy: 0.8012
# Epoch 2/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3906 - accuracy: 0.8338
# Epoch 3/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3643 - accuracy: 0.8493
# Epoch 4/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3556 - accuracy: 0.8545
# Epoch 5/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3520 - accuracy: 0.8544: 0s - loss: 0.3537 - accuracy: 0.
# Epoch 6/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3490 - accuracy: 0.8560
# Epoch 7/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3444 - accuracy: 0.8575
# Epoch 8/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3426 - accuracy: 0.8589
# Epoch 9/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3381 - accuracy: 0.8614
# Epoch 10/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3331 - accuracy: 0.8620
# Epoch 11/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3321 - accuracy: 0.8624
# Epoch 12/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3289 - accuracy: 0.8674
# Epoch 13/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3258 - accuracy: 0.8675

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(10000), loss_history.losses[0:10000])
plt.xlabel("iteration")
plt.ylabel("Loss function")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 885us/step - loss: 0.3528 - accuracy: 0.8580
# [0.3528214991092682, 0.8579999804496765]

# %%
get_con_mat(model,X_test, y_test)
