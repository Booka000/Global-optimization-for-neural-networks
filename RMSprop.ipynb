# %%
import numpy as np
import tensorflow as tf
import import_ipynb
from NN import get_dataset, get_model, get_shape, set_shape, get_con_mat, LossHistory
import matplotlib.pyplot as plt
import json
import os
from sklearn.metrics import confusion_matrix
# Out:
# importing Jupyter notebook from NN.ipynb

# %%
X_train, X_test, y_train, y_test = get_dataset()

# %%
model = get_model()

# %%
loss_history = LossHistory()

# %%
model.compile(optimizer='rmsprop', loss="binary_crossentropy", metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size = 10, epochs = 13, verbose = 1,callbacks=[loss_history])
# Out:
# Epoch 1/13
# 800/800 [==============================] - 2s 1ms/step - loss: 0.4471 - accuracy: 0.8114: 0s - loss: 0.4505 - accuracy:
# Epoch 2/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3962 - accuracy: 0.8357: 0s - l
# Epoch 3/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3747 - accuracy: 0.8487
# Epoch 4/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3650 - accuracy: 0.8543
# Epoch 5/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3595 - accuracy: 0.8572
# Epoch 6/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3572 - accuracy: 0.8580: 0s - loss: 0.3595 - ac
# Epoch 7/13
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3530 - accuracy: 0.8570
# Epoch 8/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3524 - accuracy: 0.8581
# Epoch 9/13
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3498 - accuracy: 0.8596
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(np.arange(10000), loss_history.losses[0:10000])
plt.xlabel("iteration")
plt.ylabel("Loss function")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 853us/step - loss: 0.3606 - accuracy: 0.8520
# [0.3605886399745941, 0.8519999980926514]

# %%
get_con_mat(model,X_test, y_test)
